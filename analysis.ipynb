# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from game_vis import PredictNetwork

# %%
predict_vis = PredictNetwork('bbl_json')

# %%
df = predict_vis.games.game_df

# %%
mat = predict_vis.get_prediction_matrix()

# %%
mat
# Out:
#                      Sydney Thunder  Melbourne Renegades  Brisbane Heat  \
# Perth Scorchers            0.464286             0.742857       0.724490
# Sydney Sixers              0.692857             0.757143       0.585714
# Hobart Hurricanes          0.600000             0.557143       0.557143
# Sydney Thunder             0.506912             0.528571       0.628571
# Adelaide Strikers          0.544898             0.542857       0.442857
# Melbourne Renegades        0.471429             0.454082       0.585714
# Brisbane Heat              0.342857             0.385714       0.404464
# Melbourne Stars            0.471429             0.292857       0.471429
#
#                      Melbourne Stars  Sydney Sixers  Adelaide Strikers  \
# Perth Scorchers             0.850000       0.582143           0.642857
# Sydney Sixers               0.864286       0.596429           0.585714
# Hobart Hurricanes           0.621429       0.514286           0.514286
# Sydney Thunder              0.500000       0.350000           0.469388
# Adelaide Strikers           0.478571       0.471429           0.500893
# Melbourne Renegades         0.678571       0.285714           0.471429
# Brisbane Heat               0.471429       0.321429           0.542857
# Melbourne Stars             0.414286       0.150000           0.507143
#
#                      Hobart Hurricanes  Perth Scorchers   Average
# Perth Scorchers               0.635714         0.629412  0.658970
# Sydney Sixers                 0.542857         0.489286  0.639286
# Hobart Hurricanes             0.506897         0.407143  0.534791
# Sydney Thunder                0.414286         0.564286  0.495252
# Adelaide Strikers             0.514286         0.400000  0.486974
# Melbourne Renegades           0.457143         0.285714  0.461224
# Brisbane Heat                 0.428571         0.275510  0.396604
# Melbourne Stars               0.364286         0.150000  0.352679
