# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from game_vis import PredictNetwork

# %%
predict_vis = PredictNetwork('bbl_json')
# Out:
# 'Info' object has no attribute 'player_of_match'
# 'Info' object has no attribute 'player_of_match'
# 'Info' object has no attribute 'player_of_match'
# 'Info' object has no attribute 'player_of_match'
# 'Info' object has no attribute 'player_of_match'
# 'Info' object has no attribute 'player_of_match'
# 'Info' object has no attribute 'player_of_match'

# %%
df = predict_vis.games.game_df

# %%
predict_vis.get_prediction_matrix(320)
# Out:
# C:\Users\wbmcg\PycharmProjects\BBLNN\game_vis.py:63: RuntimeWarning: invalid value encountered in scalar divide
#   form_percentage = wins_t1 / (wins_t2 + wins_t1)
# <AxesSubplot: ylabel='Home Win Odds.'>
